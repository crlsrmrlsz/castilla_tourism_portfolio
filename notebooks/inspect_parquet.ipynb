# %%
import pandas as pd
from pathlib import Path
import warnings

# %%
# Suppress potential future warnings from pandas
warnings.simplefilter(action='ignore', category=FutureWarning)

# --- Configuration ---
# Use Path for OS compatibility. '../' goes up one level from the 'notebooks' folder to the project root.
PROJECT_ROOT = Path("..") 
ANALYTICS_DATA_DIR = PROJECT_ROOT / "data" / "analytics"

# --- Pick a file to inspect ---
file_to_check = "Albacete Municipio/Diario_2H_origin_analysis.parquet"
file_path = ANALYTICS_DATA_DIR / file_to_check

# --- Load the data ---
print(f"Loading data from: {file_path}")
df = pd.read_parquet(file_path)

# --- Inspect the DataFrame ---
print("\nShape (rows, columns):", df.shape)
print("\nColumns:", df.columns.to_list())

# Display the first 5 rows
df.head(20)
# Out:
# Loading data from: ..\data\analytics\Albacete Municipio\Diario_2H_origin_analysis.parquet
#
# Shape (rows, columns): (3399756, 12)
#
# Columns: ['fecha', 'origen', 'categoriadelvisitante', 'hora', 'volumen_total', 'volumen_municipio', 'volumen_nacionalidad', 'origen_detalle', 'provincia_detalle', 'year', 'month', 'weekday']
#         fecha      origen categoriadelvisitante         hora  volumen_total  \
# 0  2022-06-01  Extranjero           En tránsito  06:00-08:00            204
# 1  2022-06-01  Extranjero           En tránsito  06:00-08:00            204
# 2  2022-06-01  Extranjero           En tránsito  06:00-08:00            204
# 3  2022-06-01  Extranjero           En tránsito  08:00-10:00            208
# 4  2022-06-01  Extranjero           En tránsito  08:00-10:00            208
# 5  2022-06-01  Extranjero           En tránsito  08:00-10:00            208
# 6  2022-06-01  Extranjero           En tránsito  08:00-10:00            208
# 7  2022-06-01  Extranjero           En tránsito  08:00-10:00            208
# 8  2022-06-01  Extranjero           En tránsito  08:00-10:00            208
# 9  2022-06-01  Extranjero           En tránsito  10:00-12:00            224
# 10 2022-06-01  Extranjero           En tránsito  10:00-12:00            224
# 11 2022-06-01  Extranjero           En tránsito  10:00-12:00            224
# 12 2022-06-01  Extranjero           En tránsito  12:00-14:00            213
# 13 2022-06-01  Extranjero           En tránsito  12:00-14:00            213
# 14 2022-06-01  Extranjero           En tránsito  12:00-14:00            213
# 15 2022-06-01  Extranjero           En tránsito  12:00-14:00            213
# 16 2022-06-01  Extranjero           En tránsito  14:00-16:00            298
# 17 2022-06-01  Extranjero           En tránsito  14:00-16:00            298
# 18 2022-06-01  Extranjero           En tránsito  14:00-16:00            298
# 19 2022-06-01  Extranjero           En tránsito  14:00-16:00            298
#
#     volumen_municipio  volumen_nacionalidad origen_detalle provincia_detalle  \
# 0                 NaN                  32.0        Bélgica              None
# 1                 NaN                  25.0       Portugal              None
# 2                 NaN                  41.0        Rumania              None
# 3                 NaN                  26.0       Alemania              None
# 4                 NaN                  20.0        Francia              None
# 5                 NaN                  24.0   Países Bajos              None
# 6                 NaN                  30.0       Portugal              None
# 7                 NaN                  32.0        Rumania              None
# 8                 NaN                  20.0        Ucrania              None
# 9                 NaN                  26.0       Alemania              None
# 10                NaN                  36.0        Francia              None
# 11                NaN                  42.0       Portugal              None
# 12                NaN                  24.0       Alemania              None
# 13                NaN                  20.0          EE.UU              None
# 14                NaN                  20.0        Polonia              None
# 15                NaN                  45.0       Portugal              None
# 16                NaN                  36.0       Alemania              None
# 17                NaN                  31.0        Bélgica              None
# 18                NaN                  24.0        Francia              None
# 19                NaN                  60.0       Portugal              None
#
#     year  month    weekday
# 0   2022      6  Wednesday
# 1   2022      6  Wednesday
# 2   2022      6  Wednesday
# 3   2022      6  Wednesday
# 4   2022      6  Wednesday
# 5   2022      6  Wednesday
# 6   2022      6  Wednesday
# 7   2022      6  Wednesday
# 8   2022      6  Wednesday
# 9   2022      6  Wednesday
# 10  2022      6  Wednesday
# 11  2022      6  Wednesday
# 12  2022      6  Wednesday
# 13  2022      6  Wednesday
# 14  2022      6  Wednesday
# 15  2022      6  Wednesday
# 16  2022      6  Wednesday
# 17  2022      6  Wednesday
# 18  2022      6  Wednesday
# 19  2022      6  Wednesday
