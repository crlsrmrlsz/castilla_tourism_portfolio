# %%
import pandas as pd
from pathlib import Path
import warnings

# %%
# Suppress potential future warnings from pandas
warnings.simplefilter(action='ignore', category=FutureWarning)

# --- Configuration ---
# Use Path for OS compatibility. '../' goes up one level from the 'notebooks' folder to the project root.
PROJECT_ROOT = Path("..") 
ANALYTICS_DATA_DIR = PROJECT_ROOT / "data" / "analytics"

# --- Pick a file to inspect ---
file_to_check = "Albacete Municipio/Diario_demographics_analysis.parquet"
file_path = ANALYTICS_DATA_DIR / file_to_check

# --- Load the data ---
print(f"Loading data from: {file_path}")
df = pd.read_parquet(file_path)

# --- Inspect the DataFrame ---
print("\nShape (rows, columns):", df.shape)
print("\nColumns:", df.columns.to_list())

# Display the first 5 rows
df.head(20)
# Out:
# Loading data from: ..\data\analytics\Albacete Municipio\Diario_demographics_analysis.parquet
#
# Shape (rows, columns): (16383, 19)
#
# Columns: ['fecha', 'origen', 'categoriadelvisitante', 'volumen_total', 'volumen_edad_18-24', 'volumen_edad_25-34', 'volumen_edad_35-44', 'volumen_edad_45-54', 'volumen_edad_55-64', 'volumen_edad_65 o más', 'volumen_edad_<18', 'volumen_edad_acumulado', 'volumen_genero_acumulado', 'volumen_genero_h', 'volumen_genero_m', 'volumen_genero_nr', 'year', 'month', 'weekday']
#         fecha   origen               categoriadelvisitante  volumen_total  \
# 0  2022-06-01    Local                         En tránsito           2898
# 1  2022-06-01    Local                       Excursionista           2539
# 2  2022-06-01    Local            Excursionista recurrente           4621
# 3  2022-06-01    Local              Habitualmente presente           2214
# 4  2022-06-01    Local  Habitualmente presente en tránsito            290
# 5  2022-06-01    Local                           Residente         114290
# 6  2022-06-01    Local               Residente en tránsito           1150
# 7  2022-06-01    Local                             Turista            745
# 8  2022-06-01    Local                 Turista en tránsito             74
# 9  2022-06-01  NoLocal                         En tránsito          25020
# 10 2022-06-01  NoLocal                       Excursionista           7331
# 11 2022-06-01  NoLocal            Excursionista recurrente           2322
# 12 2022-06-01  NoLocal              Habitualmente presente           1720
# 13 2022-06-01  NoLocal  Habitualmente presente en tránsito            155
# 14 2022-06-01  NoLocal                           Residente           9312
# 15 2022-06-01  NoLocal               Residente en tránsito            172
# 16 2022-06-01  NoLocal                             Turista           1551
# 17 2022-06-01  NoLocal                 Turista en tránsito             69
# 18 2022-06-02    Local                         En tránsito           2519
# 19 2022-06-02    Local                       Excursionista           2275
#
#     volumen_edad_18-24  volumen_edad_25-34  volumen_edad_35-44  \
# 0                109.0               259.0               491.0
# 1                 68.0               218.0               327.0
# 2                217.0               471.0               766.0
# 3                 99.0               193.0               308.0
# 4                  NaN                 NaN                27.0
# 5               6882.0             11397.0             17058.0
# 6                 47.0               112.0               157.0
# 7                  NaN                68.0                73.0
# 8                  NaN                 NaN                 NaN
# 9                728.0              1692.0              3089.0
# 10               188.0               547.0               880.0
# 11                91.0               196.0               285.0
# 12                 NaN               108.0               159.0
# 13                 NaN                 NaN                34.0
# 14               400.0               767.0              1041.0
# 15                 NaN                 NaN                 NaN
# 16                63.0                69.0               128.0
# 17                 NaN                 NaN                 NaN
