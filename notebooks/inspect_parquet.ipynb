# %%
import pandas as pd
from pathlib import Path
import warnings

# %%
# Suppress potential future warnings from pandas
warnings.simplefilter(action='ignore', category=FutureWarning)

# --- Configuration ---
# Use Path for OS compatibility. '../' goes up one level from the 'notebooks' folder to the project root.
PROJECT_ROOT = Path("..") 
ANALYTICS_DATA_DIR = PROJECT_ROOT / "data" / "analytics"

# --- Pick a file to inspect ---
file_to_check = "Albacete Municipio/Diario_2H_demographics_analysis.parquet"
file_path = ANALYTICS_DATA_DIR / file_to_check

# --- Load the data ---
print(f"Loading data from: {file_path}")
df = pd.read_parquet(file_path)

# --- Inspect the DataFrame ---
print("\nShape (rows, columns):", df.shape)
print("\nColumns:", df.columns.to_list())

# Display the first 5 rows
df.head(20)
# Out:
# Loading data from: ..\data\analytics\Albacete Municipio\Diario_2H_demographics_analysis.parquet
#
# Shape (rows, columns): (169666, 8)
#
# Columns: ['fecha', 'origen', 'categoriadelvisitante', 'hora', 'volumen_total', 'year', 'month', 'weekday']
#         fecha      origen     categoriadelvisitante         hora  \
# 0  2022-06-01  Extranjero               En tránsito  06:00-08:00
# 1  2022-06-01  Extranjero               En tránsito  08:00-10:00
# 2  2022-06-01  Extranjero               En tránsito  10:00-12:00
# 3  2022-06-01  Extranjero               En tránsito  12:00-14:00
# 4  2022-06-01  Extranjero               En tránsito  14:00-16:00
# 5  2022-06-01  Extranjero               En tránsito  16:00-18:00
# 6  2022-06-01  Extranjero               En tránsito  18:00-20:00
# 7  2022-06-01  Extranjero               En tránsito  20:00-22:00
# 8  2022-06-01  Extranjero               En tránsito  22:00-00:00
# 9  2022-06-01  Extranjero             Excursionista  06:00-08:00
# 10 2022-06-01  Extranjero             Excursionista  08:00-10:00
# 11 2022-06-01  Extranjero             Excursionista  10:00-12:00
# 12 2022-06-01  Extranjero             Excursionista  12:00-14:00
# 13 2022-06-01  Extranjero             Excursionista  14:00-16:00
# 14 2022-06-01  Extranjero             Excursionista  16:00-18:00
# 15 2022-06-01  Extranjero             Excursionista  18:00-20:00
# 16 2022-06-01  Extranjero             Excursionista  20:00-22:00
# 17 2022-06-01  Extranjero  Excursionista recurrente  06:00-08:00
# 18 2022-06-01  Extranjero  Excursionista recurrente  08:00-10:00
# 19 2022-06-01  Extranjero  Excursionista recurrente  10:00-12:00
#
#     volumen_total  year  month    weekday
# 0             204  2022      6  Wednesday
# 1             208  2022      6  Wednesday
# 2             224  2022      6  Wednesday
# 3             213  2022      6  Wednesday
# 4             298  2022      6  Wednesday
# 5             258  2022      6  Wednesday
# 6             130  2022      6  Wednesday
# 7             256  2022      6  Wednesday
# 8              53  2022      6  Wednesday
# 9              60  2022      6  Wednesday
# 10             76  2022      6  Wednesday
# 11            108  2022      6  Wednesday
# 12            136  2022      6  Wednesday
# 13             98  2022      6  Wednesday
# 14             89  2022      6  Wednesday
# 15             89  2022      6  Wednesday
# 16             39  2022      6  Wednesday
# 17             55  2022      6  Wednesday
# 18             63  2022      6  Wednesday
# 19             52  2022      6  Wednesday
