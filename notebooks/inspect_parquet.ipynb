# %%
import pandas as pd
from pathlib import Path
import warnings

# %%
# Suppress potential future warnings from pandas
warnings.simplefilter(action='ignore', category=FutureWarning)

# --- Configuration ---
# Use Path for OS compatibility. '../' goes up one level from the 'notebooks' folder to the project root.
PROJECT_ROOT = Path("..") 
ANALYTICS_DATA_DIR = PROJECT_ROOT / "data" / "analytics"

# --- Pick a file to inspect ---
file_to_check = "CCAA Castilla-La Mancha/Llegada_demographics_analysis.parquet"
file_path = ANALYTICS_DATA_DIR / file_to_check

# --- Load the data ---
print(f"Loading data from: {file_path}")
df = pd.read_parquet(file_path)

# --- Inspect the DataFrame ---
print("\nShape (rows, columns):", df.shape)
print("\nColumns:", df.columns.to_list())

# Display the first 5 rows
df.head(20)
# Out:
# Loading data from: ..\data\analytics\CCAA Castilla-La Mancha\Llegada_demographics_analysis.parquet
#
# Shape (rows, columns): (5484, 17)
#
# Columns: ['fecha', 'origen', 'categoriadelvisitante', 'volumen_total', 'volumen_edad_18-24', 'volumen_edad_25-34', 'volumen_edad_35-44', 'volumen_edad_45-54', 'volumen_edad_55-64', 'volumen_edad_65 o más', 'volumen_edad_<18', 'volumen_genero_h', 'volumen_genero_m', 'volumen_genero_nr', 'year', 'month', 'weekday']
#         fecha      origen   categoriadelvisitante  volumen_total  \
# 0  2022-06-01  Extranjero  Habitualmente presente            272
# 1  2022-06-01  Extranjero                 Turista           6310
# 2  2022-06-01       Local  Habitualmente presente           2542
# 3  2022-06-01       Local                 Turista           1106
# 4  2022-06-01     NoLocal  Habitualmente presente           6918
# 5  2022-06-01     NoLocal                 Turista          12707
# 6  2022-06-02  Extranjero  Habitualmente presente            279
# 7  2022-06-02  Extranjero                 Turista           6285
# 8  2022-06-02       Local  Habitualmente presente           3464
# 9  2022-06-02       Local                 Turista           1343
# 10 2022-06-02     NoLocal  Habitualmente presente           9813
# 11 2022-06-02     NoLocal                 Turista          14154
# 12 2022-06-03  Extranjero  Habitualmente presente            304
# 13 2022-06-03  Extranjero                 Turista           7145
# 14 2022-06-03       Local  Habitualmente presente          13805
# 15 2022-06-03       Local                 Turista           3050
# 16 2022-06-03     NoLocal  Habitualmente presente          51540
# 17 2022-06-03     NoLocal                 Turista          53769
# 18 2022-06-04  Extranjero  Habitualmente presente            318
# 19 2022-06-04  Extranjero                 Turista           6500
#
#     volumen_edad_18-24  volumen_edad_25-34  volumen_edad_35-44  \
# 0                  NaN                 NaN                 NaN
# 1                  NaN                 NaN                 NaN
# 2                 34.0               185.0               295.0
# 3                 57.0                51.0                75.0
# 4                126.0               461.0               776.0
# 5                262.0               824.0              1557.0
# 6                  NaN                 NaN                 NaN
# 7                  NaN                 NaN                 NaN
# 8                109.0               287.0               389.0
# 9                  NaN                95.0               111.0
# 10               282.0               511.0               989.0
# 11               281.0               893.0              1715.0
# 12                 NaN                 NaN                 NaN
# 13                 NaN                 NaN                 NaN
# 14               580.0              1086.0              1583.0
# 15                45.0               283.0               304.0
# 16              2819.0              4566.0              7183.0
# 17              2136.0              4845.0              7996.0
# 18                 NaN                 NaN                 NaN
# 19                 NaN                 NaN                 NaN
#
#     volumen_edad_45-54  volumen_edad_55-64  volumen_edad_65 o más  \
# 0                  NaN                 NaN                    NaN
# 1                  NaN                 NaN                    NaN
# 2                278.0               353.0                  287.0
# 3                109.0               105.0                  226.0
# 4                745.0               763.0                 1069.0
# 5               1532.0              1180.0                 1670.0
# 6                  NaN                 NaN                    NaN
# 7                  NaN                 NaN                    NaN
# 8                493.0               454.0                  278.0
# 9                134.0               195.0                  193.0
# 10              1154.0              1028.0                 2081.0
# 11              1821.0              1387.0                 1913.0
# 12                 NaN                 NaN                    NaN
# 13                 NaN                 NaN                    NaN
# 14              1901.0              2044.0                 1702.0
# 15               317.0               430.0                  338.0
# 16              8551.0              7042.0                 8963.0
# 17              8214.0              6585.0                 7339.0
# 18                 NaN                 NaN                    NaN
# 19                 NaN                 NaN                    NaN
#
#     volumen_edad_<18  volumen_genero_h  volumen_genero_m  volumen_genero_nr  \
# 0                NaN               NaN               NaN                NaN
# 1                NaN               NaN               NaN                NaN
# 2              192.0             948.0             676.0                NaN
# 3               43.0             319.0             347.0                NaN
# 4              523.0            2768.0            1695.0                NaN
# 5              810.0            4715.0            3115.0                NaN
# 6                NaN               NaN               NaN                NaN
# 7                NaN               NaN               NaN                NaN
# 8              314.0            1317.0            1007.0                NaN
# 9               66.0             450.0             355.0                NaN
# 10            1043.0            4305.0            2783.0                NaN
# 11            1027.0            5395.0            3642.0                NaN
# 12               NaN               NaN               NaN                NaN
# 13               NaN               NaN               NaN                NaN
# 14            1866.0            6358.0            4404.0                NaN
# 15             263.0            1137.0             843.0                NaN
# 16            8406.0           26677.0           20846.0                NaN
# 17            7529.0           24764.0           19861.0                NaN
# 18               NaN               NaN               NaN                NaN
# 19               NaN               NaN               NaN                NaN
#
#     year  month    weekday
# 0   2022      6  Wednesday
# 1   2022      6  Wednesday
# 2   2022      6  Wednesday
# 3   2022      6  Wednesday
# 4   2022      6  Wednesday
# 5   2022      6  Wednesday
# 6   2022      6   Thursday
# 7   2022      6   Thursday
# 8   2022      6   Thursday
# 9   2022      6   Thursday
# 10  2022      6   Thursday
# 11  2022      6   Thursday
# 12  2022      6     Friday
# 13  2022      6     Friday
# 14  2022      6     Friday
# 15  2022      6     Friday
# 16  2022      6     Friday
# 17  2022      6     Friday
# 18  2022      6   Saturday
# 19  2022      6   Saturday

# %%
unique_values = df['categoriadelvisitante'].unique()
print(unique_values)
# Out:
# ['Habitualmente presente' 'Turista']

# %%
len(df)
# Out:
# 5484
